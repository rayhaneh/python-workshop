# %%
import pandas as pd

# %%
data = pd.read_csv("claims-data.csv")

# %%
data
# Out:
#      trans_date             uploader       vendor  amount tax_type  tax_rate
# 0    2018-01-01          Jane Jetson    tinyhouse  112.61      HST        13
# 1    2018-01-02  Squidward Tentacles    tinyhouse  194.61      GST         5
# 2    2018-01-03            Olive Oyl    tinyhouse  112.92      HST        13
# 3    2018-01-07  Squidward Tentacles    tinyhouse  150.34      GST         5
# 4    2018-01-09         Elroy Jetson    tinyhouse  101.07      HST        13
# 5    2018-01-10      Speedy Gonzales    tinyhouse  115.11      HST        13
# 6    2018-01-12     Eliza Thornberry    tinyhouse  164.65      HST        13
# 7    2018-01-13      Helga G. Pataki     ponistic  110.50      GST         5
# 8    2018-01-14  Squidward Tentacles     ponistic  171.10      GST         5
# 9    2018-01-20        Peter Griffin     ponistic  155.17      HST        13
# 10   2018-01-22      Chuckie Finster    tinyhouse  104.60      HST        13
# 11   2018-01-22            Olive Oyl     ponistic  196.40      HST        13
# 12   2018-01-27        Shaggy Rogers     ponistic  125.29      GST         5
# 13   2018-01-28      Foghorn Leghorn     ponistic  164.58      GST         5
# 14   2018-01-29         Tina Belcher     ponistic  129.30      GST         5
# 15   2018-01-31    Wendy Testaburger    tinyhouse  175.47      GST         5
# 16   2018-02-01       Jessica Rabbit    tinyhouse  144.18      GST         5
# 17   2018-02-03    Wendy Testaburger    tinyhouse  146.67      HST        13
# 18   2018-02-04         Yosemite Sam     ponistic  102.24      HST        13
# 19   2018-02-06        Homer Simpson  foodieguide  133.06      GST         5
# 20   2018-02-07         Elroy Jetson     ponistic  168.29      HST        13
# 21   2018-02-07            Olive Oyl    tinyhouse  170.25      HST        13
# 22   2018-02-09         Sandy Cheeks     ponistic  160.06      HST        13
# 23   2018-02-09         Sandy Cheeks     ponistic  160.83      HST        13
# 24   2018-02-10          Jane Jetson     ponistic  190.67      GST         5
# 25   2018-02-12      Helga G. Pataki     ponistic  183.94      HST        13
# 26   2018-02-15      Speedy Gonzales     ponistic  177.11      HST        13
# 27   2018-02-17      Helga G. Pataki    tinyhouse  181.29      HST        13
# 28   2018-02-22            Olive Oyl    tinyhouse  108.46      HST        13
# 29   2018-02-24        Homer Simpson     ponistic  101.61      HST        13
# ..          ...                  ...          ...     ...      ...       ...
# 270  2019-03-24          Penny Proud    tinyhouse  183.46      GST         5
# 271  2019-03-26         Elroy Jetson     ponistic  178.38      GST         5
# 272  2019-03-29      Helga G. Pataki    tinyhouse  173.98      HST        13
# 273  2019-03-30         Elroy Jetson    tinyhouse  184.40      GST         5
# 274  2019-04-05         Tina Belcher     ponistic  113.34      HST        13
# 275  2019-04-07        Shaggy Rogers     ponistic  115.59      GST         5
# 276  2019-04-08  Squidward Tentacles    tinyhouse  149.34      HST        13
# 277  2019-04-09     Charles M. Burns    tinyhouse  858.36      HST        13
# 278  2019-04-09  Squidward Tentacles     ponistic  149.65      HST        13
# 279  2019-04-12           Elmer Fudd    tinyhouse  104.69      GST         5
# 280  2019-04-13      Kenny McCormick     ponistic  113.85      GST         5
# 281  2019-04-14        Peter Griffin     ponistic  132.60      GST         5
# 282  2019-04-17      Speedy Gonzales     ponistic  180.34      HST        13
# 283  2019-04-18         Patrick Star    tinyhouse  167.53      GST         5
# 284  2019-04-19         Eric Cartman    tinyhouse  168.98      HST        13
# 285  2019-04-19          Penny Proud     ponistic  128.14      HST        13
# 286  2019-04-20         Eric Cartman     ponistic  197.92      GST         5
# 287  2019-04-21  Squidward Tentacles    tinyhouse  109.01      HST        13
# 288  2019-04-26      Kenny McCormick  foodieguide  163.89      GST         5
# 289  2019-04-26         Sandy Cheeks     ponistic  119.68      HST        13
# 290  2019-04-27        Peter Griffin    tinyhouse  188.05      HST        13
# 291  2019-04-27      Speedy Gonzales    tinyhouse  143.04      HST        13
# 292  2019-04-30      Helga G. Pataki     ponistic  133.87      HST        13
# 293  2019-05-02      Foghorn Leghorn    tinyhouse  187.24      HST        13
# 294  2019-05-03            Olive Oyl     ponistic  105.78      GST         5
# 295  2019-05-07           Elmer Fudd     ponistic  154.17      HST        13
# 296  2019-05-07         Eric Cartman    tinyhouse  135.79      GST         5
# 297  2019-05-12         Elroy Jetson     ponistic  183.37      HST        13
# 298  2019-05-14    Wendy Testaburger    tinyhouse  131.30      HST        13
# 299  2019-05-15        Peter Griffin    tinyhouse  193.40      HST        13
#
# [300 rows x 6 columns]

# %%
data.head()
# Out:
#    trans_date             uploader     vendor  amount tax_type  tax_rate
# 0  2018-01-01          Jane Jetson  tinyhouse  112.61      HST        13
# 1  2018-01-02  Squidward Tentacles  tinyhouse  194.61      GST         5
# 2  2018-01-03            Olive Oyl  tinyhouse  112.92      HST        13
# 3  2018-01-07  Squidward Tentacles  tinyhouse  150.34      GST         5
# 4  2018-01-09         Elroy Jetson  tinyhouse  101.07      HST        13

# %%
data.head(10)
# Out:
#    trans_date             uploader     vendor  amount tax_type  tax_rate
# 0  2018-01-01          Jane Jetson  tinyhouse  112.61      HST        13
# 1  2018-01-02  Squidward Tentacles  tinyhouse  194.61      GST         5
# 2  2018-01-03            Olive Oyl  tinyhouse  112.92      HST        13
# 3  2018-01-07  Squidward Tentacles  tinyhouse  150.34      GST         5
# 4  2018-01-09         Elroy Jetson  tinyhouse  101.07      HST        13
# 5  2018-01-10      Speedy Gonzales  tinyhouse  115.11      HST        13
# 6  2018-01-12     Eliza Thornberry  tinyhouse  164.65      HST        13
# 7  2018-01-13      Helga G. Pataki   ponistic  110.50      GST         5
# 8  2018-01-14  Squidward Tentacles   ponistic  171.10      GST         5
# 9  2018-01-20        Peter Griffin   ponistic  155.17      HST        13

# %%
data.tail()
# Out:
#      trans_date           uploader     vendor  amount tax_type  tax_rate
# 295  2019-05-07         Elmer Fudd   ponistic  154.17      HST        13
# 296  2019-05-07       Eric Cartman  tinyhouse  135.79      GST         5
# 297  2019-05-12       Elroy Jetson   ponistic  183.37      HST        13
# 298  2019-05-14  Wendy Testaburger  tinyhouse  131.30      HST        13
# 299  2019-05-15      Peter Griffin  tinyhouse  193.40      HST        13

# %%
data.tail(10)
# Out:
#      trans_date           uploader     vendor  amount tax_type  tax_rate
# 290  2019-04-27      Peter Griffin  tinyhouse  188.05      HST        13
# 291  2019-04-27    Speedy Gonzales  tinyhouse  143.04      HST        13
# 292  2019-04-30    Helga G. Pataki   ponistic  133.87      HST        13
# 293  2019-05-02    Foghorn Leghorn  tinyhouse  187.24      HST        13
# 294  2019-05-03          Olive Oyl   ponistic  105.78      GST         5
# 295  2019-05-07         Elmer Fudd   ponistic  154.17      HST        13
# 296  2019-05-07       Eric Cartman  tinyhouse  135.79      GST         5
# 297  2019-05-12       Elroy Jetson   ponistic  183.37      HST        13
# 298  2019-05-14  Wendy Testaburger  tinyhouse  131.30      HST        13
# 299  2019-05-15      Peter Griffin  tinyhouse  193.40      HST        13

# %%
data[10:15]
# Out:
#     trans_date         uploader     vendor  amount tax_type  tax_rate
# 10  2018-01-22  Chuckie Finster  tinyhouse  104.60      HST        13
# 11  2018-01-22        Olive Oyl   ponistic  196.40      HST        13
# 12  2018-01-27    Shaggy Rogers   ponistic  125.29      GST         5
# 13  2018-01-28  Foghorn Leghorn   ponistic  164.58      GST         5
# 14  2018-01-29     Tina Belcher   ponistic  129.30      GST         5

# %%
data[0:300:50]
# Out:
#      trans_date             uploader     vendor  amount tax_type  tax_rate
# 0    2018-01-01          Jane Jetson  tinyhouse  112.61      HST        13
# 50   2018-04-03       Jessica Rabbit   ponistic  189.25      HST        13
# 100  2018-06-15      Chuckie Finster  tinyhouse  100.35      HST        13
# 150  2018-09-02  Squidward Tentacles   ponistic  116.16      HST        13
# 200  2018-11-28      Fred Flintstone   ponistic  142.02      GST         5
# 250  2019-02-05        Homer Simpson   ponistic  124.96      HST        13

# %%
data[::50]
# Out:
#      trans_date             uploader     vendor  amount tax_type  tax_rate
# 0    2018-01-01          Jane Jetson  tinyhouse  112.61      HST        13
# 50   2018-04-03       Jessica Rabbit   ponistic  189.25      HST        13
# 100  2018-06-15      Chuckie Finster  tinyhouse  100.35      HST        13
# 150  2018-09-02  Squidward Tentacles   ponistic  116.16      HST        13
# 200  2018-11-28      Fred Flintstone   ponistic  142.02      GST         5
# 250  2019-02-05        Homer Simpson   ponistic  124.96      HST        13

# %%
data[::-20]
# Out:
#      trans_date           uploader       vendor  amount tax_type  tax_rate
# 299  2019-05-15      Peter Griffin    tinyhouse  193.40      HST        13
# 279  2019-04-12         Elmer Fudd    tinyhouse  104.69      GST         5
# 259  2019-02-19    Fred Flintstone    tinyhouse  150.61      HST        13
# 239  2019-01-17   Charles M. Burns    tinyhouse  535.89      GST         5
# 219  2018-12-23    Helga G. Pataki     ponistic  139.97      HST        13
# 199  2018-11-23        Penny Proud     ponistic  155.85      HST        13
# 179  2018-10-19       Elroy Jetson     ponistic  128.47      HST        13
# 159  2018-09-14        Penny Proud    tinyhouse  108.98      GST         5
# 139  2018-08-15        Penny Proud     ponistic  121.73      HST        13
# 119  2018-07-14     Jessica Rabbit    tinyhouse  136.07      GST         5
# 99   2018-06-14     Jessica Rabbit        prema  157.58      HST        13
# 79   2018-05-20    Kenny McCormick    tinyhouse  188.40      HST        13
# 59   2018-04-27  Wendy Testaburger     ponistic  160.61      HST        13
# 39   2018-03-09  Wendy Testaburger    tinyhouse  168.07      HST        13
# 19   2018-02-06      Homer Simpson  foodieguide  133.06      GST         5

# %%
#number of rows

# %%
len(data)
# Out:
# 300

# %%
#columns

# %%
data.columns
# Out:
# Index(['trans_date', 'uploader', 'vendor', 'amount', 'tax_type', 'tax_rate'], dtype='object')

# %%
len(data.columns)
# Out:
# 6

# %%
data["uploader"]
# Out:
# 0              Jane Jetson
# 1      Squidward Tentacles
# 2                Olive Oyl
# 3      Squidward Tentacles
# 4             Elroy Jetson
# 5          Speedy Gonzales
# 6         Eliza Thornberry
# 7          Helga G. Pataki
# 8      Squidward Tentacles
# 9            Peter Griffin
# 10         Chuckie Finster
# 11               Olive Oyl
# 12           Shaggy Rogers
# 13         Foghorn Leghorn
# 14            Tina Belcher
# 15       Wendy Testaburger
# 16          Jessica Rabbit
# 17       Wendy Testaburger
# 18            Yosemite Sam
# 19           Homer Simpson
# 20            Elroy Jetson
# 21               Olive Oyl
# 22            Sandy Cheeks
# 23            Sandy Cheeks
# 24             Jane Jetson
# 25         Helga G. Pataki
# 26         Speedy Gonzales
# 27         Helga G. Pataki
# 28               Olive Oyl
# 29           Homer Simpson
#               ...
# 270            Penny Proud
# 271           Elroy Jetson
# 272        Helga G. Pataki
# 273           Elroy Jetson
# 274           Tina Belcher
# 275          Shaggy Rogers
# 276    Squidward Tentacles
# 277       Charles M. Burns
# 278    Squidward Tentacles
# 279             Elmer Fudd
# 280        Kenny McCormick
# 281          Peter Griffin
# 282        Speedy Gonzales
# 283           Patrick Star
# 284           Eric Cartman
# 285            Penny Proud
# 286           Eric Cartman
# 287    Squidward Tentacles
# 288        Kenny McCormick
# 289           Sandy Cheeks
# 290          Peter Griffin
# 291        Speedy Gonzales
# 292        Helga G. Pataki
# 293        Foghorn Leghorn
# 294              Olive Oyl
# 295             Elmer Fudd
# 296           Eric Cartman
# 297           Elroy Jetson
# 298      Wendy Testaburger
# 299          Peter Griffin
# Name: uploader, Length: 300, dtype: object

# %%
data.uploader.head()
# Out:
# 0            Jane Jetson
# 1    Squidward Tentacles
# 2              Olive Oyl
# 3    Squidward Tentacles
# 4           Elroy Jetson
# Name: uploader, dtype: object

# %%
data.head().uploader
# Out:
# 0            Jane Jetson
# 1    Squidward Tentacles
# 2              Olive Oyl
# 3    Squidward Tentacles
# 4           Elroy Jetson
# Name: uploader, dtype: object

# %%
data["uploader"].unique()
# Out:
# array(['Jane Jetson', 'Squidward Tentacles', 'Olive Oyl', 'Elroy Jetson',
#        'Speedy Gonzales', 'Eliza Thornberry', 'Helga G. Pataki',
#        'Peter Griffin', 'Chuckie Finster', 'Shaggy Rogers',
#        'Foghorn Leghorn', 'Tina Belcher', 'Wendy Testaburger',
#        'Jessica Rabbit', 'Yosemite Sam', 'Homer Simpson', 'Sandy Cheeks',
#        'Charles M. Burns', 'Elmer Fudd', 'Kenny McCormick', 'Penny Proud',
#        'Lucy van Pelt', 'Eric Cartman', 'Patrick Star', 'Fred Flintstone'],
#       dtype=object)

# %%
data[["uploader", "vendor"]].head()
# Out:
#               uploader     vendor
# 0          Jane Jetson  tinyhouse
# 1  Squidward Tentacles  tinyhouse
# 2            Olive Oyl  tinyhouse
# 3  Squidward Tentacles  tinyhouse
# 4         Elroy Jetson  tinyhouse

# %%
data[["uploader", "vendor"]][4:8]
# Out:
#            uploader     vendor
# 4      Elroy Jetson  tinyhouse
# 5   Speedy Gonzales  tinyhouse
# 6  Eliza Thornberry  tinyhouse
# 7   Helga G. Pataki   ponistic

# %%
data[4:8][["uploader", "vendor"]]
# Out:
#            uploader     vendor
# 4      Elroy Jetson  tinyhouse
# 5   Speedy Gonzales  tinyhouse
# 6  Eliza Thornberry  tinyhouse
# 7   Helga G. Pataki   ponistic

# %%
data.sample(5)
# Out:
#      trans_date             uploader     vendor  amount tax_type  tax_rate
# 83   2018-05-21         Tina Belcher   ponistic  108.81      HST        13
# 3    2018-01-07  Squidward Tentacles  tinyhouse  150.34      GST         5
# 276  2019-04-08  Squidward Tentacles  tinyhouse  149.34      HST        13
# 225  2018-12-31        Lucy van Pelt   ponistic  167.20      GST         5
# 188  2018-11-08      Chuckie Finster   ponistic  166.72      HST        13

# %%
data["tax_amount"] = data.amount * data.tax_rate / 100

# %%
data.sample(5)
# Out:
#      trans_date           uploader     vendor  amount tax_type  tax_rate  \
# 45   2018-03-28  Wendy Testaburger   ponistic  128.42      HST        13
# 62   2018-05-03      Shaggy Rogers   ponistic  164.56      HST        13
# 24   2018-02-10        Jane Jetson   ponistic  190.67      GST         5
# 208  2018-12-05      Peter Griffin  tinyhouse  144.07      HST        13
# 9    2018-01-20      Peter Griffin   ponistic  155.17      HST        13
#
#      tax_amount
# 45      16.6946
# 62      21.3928
# 24       9.5335
# 208     18.7291
# 9       20.1721

# %%
data[data.amount < 105]
# Out:
#      trans_date           uploader     vendor  amount tax_type  tax_rate  \
# 4    2018-01-09       Elroy Jetson  tinyhouse  101.07      HST        13
# 10   2018-01-22    Chuckie Finster  tinyhouse  104.60      HST        13
# 18   2018-02-04       Yosemite Sam   ponistic  102.24      HST        13
# 29   2018-02-24      Homer Simpson   ponistic  101.61      HST        13
# 47   2018-04-02       Yosemite Sam   ponistic  100.04      HST        13
# 51   2018-04-03      Peter Griffin   ponistic  102.71      GST         5
# 55   2018-04-17      Homer Simpson   ponistic  104.19      GST         5
# 82   2018-05-21       Sandy Cheeks   ponistic  100.05      HST        13
# 91   2018-06-01      Lucy van Pelt   ponistic  101.80      HST        13
# 100  2018-06-15    Chuckie Finster  tinyhouse  100.35      HST        13
# 102  2018-06-18       Patrick Star   ponistic  102.33      HST        13
# 104  2018-06-19  Wendy Testaburger   ponistic  102.34      HST        13
# 146  2018-08-26      Lucy van Pelt   ponistic  102.56      HST        13
# 157  2018-09-12    Fred Flintstone   ponistic  101.71      HST        13
# 214  2018-12-19      Shaggy Rogers     delict  104.69      HST        13
# 264  2019-03-12        Jane Jetson  tinyhouse  101.32      HST        13
# 279  2019-04-12         Elmer Fudd  tinyhouse  104.69      GST         5
#
#      tax_amount
# 4       13.1391
# 10      13.5980
# 18      13.2912
# 29      13.2093
# 47      13.0052
# 51       5.1355
# 55       5.2095
# 82      13.0065
# 91      13.2340
# 100     13.0455
# 102     13.3029
# 104     13.3042
# 146     13.3328
# 157     13.2223
# 214     13.6097
# 264     13.1716
# 279      5.2345

# %%
thdata = data[data.vendor == "tinyhouse"].copy()

# %%
avg = thdata.amount.mean()

# %%
std = thdata.amount.std()

# %%
thdata["z_score"] = (thdata.amount - avg) / std

# %%
thdata
# Out:
#      trans_date             uploader     vendor  amount tax_type  tax_rate  \
# 0    2018-01-01          Jane Jetson  tinyhouse  112.61      HST        13
# 1    2018-01-02  Squidward Tentacles  tinyhouse  194.61      GST         5
# 2    2018-01-03            Olive Oyl  tinyhouse  112.92      HST        13
# 3    2018-01-07  Squidward Tentacles  tinyhouse  150.34      GST         5
# 4    2018-01-09         Elroy Jetson  tinyhouse  101.07      HST        13
# 5    2018-01-10      Speedy Gonzales  tinyhouse  115.11      HST        13
# 6    2018-01-12     Eliza Thornberry  tinyhouse  164.65      HST        13
# 10   2018-01-22      Chuckie Finster  tinyhouse  104.60      HST        13
# 15   2018-01-31    Wendy Testaburger  tinyhouse  175.47      GST         5
# 16   2018-02-01       Jessica Rabbit  tinyhouse  144.18      GST         5
# 17   2018-02-03    Wendy Testaburger  tinyhouse  146.67      HST        13
# 21   2018-02-07            Olive Oyl  tinyhouse  170.25      HST        13
# 27   2018-02-17      Helga G. Pataki  tinyhouse  181.29      HST        13
# 28   2018-02-22            Olive Oyl  tinyhouse  108.46      HST        13
# 31   2018-02-25     Eliza Thornberry  tinyhouse  187.24      GST         5
# 37   2018-03-06      Foghorn Leghorn  tinyhouse  164.51      HST        13
# 38   2018-03-07      Kenny McCormick  tinyhouse  194.24      HST        13
# 39   2018-03-09    Wendy Testaburger  tinyhouse  168.07      HST        13
# 40   2018-03-15     Charles M. Burns  tinyhouse  707.05      GST         5
# 46   2018-03-31      Chuckie Finster  tinyhouse  183.11      HST        13
# 48   2018-04-03         Elroy Jetson  tinyhouse  129.65      GST         5
# 52   2018-04-06         Yosemite Sam  tinyhouse  112.57      GST         5
# 53   2018-04-10         Elroy Jetson  tinyhouse  195.21      HST        13
# 54   2018-04-16          Jane Jetson  tinyhouse  174.91      GST         5
# 61   2018-05-03         Patrick Star  tinyhouse  169.30      HST        13
# 63   2018-05-05     Eliza Thornberry  tinyhouse  120.17      HST        13
# 64   2018-05-05        Peter Griffin  tinyhouse  146.73      HST        13
# 66   2018-05-08     Charles M. Burns  tinyhouse  313.76      HST        13
# 72   2018-05-12      Kenny McCormick  tinyhouse  155.13      GST         5
# 73   2018-05-15     Eliza Thornberry  tinyhouse  139.66      GST         5
# ..          ...                  ...        ...     ...      ...       ...
# 244  2019-01-24      Foghorn Leghorn  tinyhouse  182.06      HST        13
# 245  2019-01-25      Fred Flintstone  tinyhouse  158.89      HST        13
# 246  2019-01-25      Kenny McCormick  tinyhouse  159.57      HST        13
# 249  2019-02-03         Tina Belcher  tinyhouse  199.96      HST        13
# 252  2019-02-10         Yosemite Sam  tinyhouse  163.22      GST         5
# 254  2019-02-12         Sandy Cheeks  tinyhouse  184.54      GST         5
# 258  2019-02-14    Wendy Testaburger  tinyhouse  172.39      HST        13
# 259  2019-02-19      Fred Flintstone  tinyhouse  150.61      HST        13
# 261  2019-03-06         Eric Cartman  tinyhouse  118.30      HST        13
# 262  2019-03-09     Eliza Thornberry  tinyhouse  114.80      HST        13
# 263  2019-03-10            Olive Oyl  tinyhouse  180.56      GST         5
# 264  2019-03-12          Jane Jetson  tinyhouse  101.32      HST        13
# 265  2019-03-13        Shaggy Rogers  tinyhouse  193.71      HST        13
# 267  2019-03-18         Yosemite Sam  tinyhouse  199.34      HST        13
# 268  2019-03-19        Lucy van Pelt  tinyhouse  136.57      HST        13
# 270  2019-03-24          Penny Proud  tinyhouse  183.46      GST         5
# 272  2019-03-29      Helga G. Pataki  tinyhouse  173.98      HST        13
# 273  2019-03-30         Elroy Jetson  tinyhouse  184.40      GST         5
# 276  2019-04-08  Squidward Tentacles  tinyhouse  149.34      HST        13
# 277  2019-04-09     Charles M. Burns  tinyhouse  858.36      HST        13
# 279  2019-04-12           Elmer Fudd  tinyhouse  104.69      GST         5
# 283  2019-04-18         Patrick Star  tinyhouse  167.53      GST         5
# 284  2019-04-19         Eric Cartman  tinyhouse  168.98      HST        13
# 287  2019-04-21  Squidward Tentacles  tinyhouse  109.01      HST        13
# 290  2019-04-27        Peter Griffin  tinyhouse  188.05      HST        13
# 291  2019-04-27      Speedy Gonzales  tinyhouse  143.04      HST        13
# 293  2019-05-02      Foghorn Leghorn  tinyhouse  187.24      HST        13
# 296  2019-05-07         Eric Cartman  tinyhouse  135.79      GST         5
# 298  2019-05-14    Wendy Testaburger  tinyhouse  131.30      HST        13
# 299  2019-05-15        Peter Griffin  tinyhouse  193.40      HST        13
#
#      tax_amount   z_score
# 0       14.6393 -0.612957
# 1        9.7305  0.280295
# 2       14.6796 -0.609580
# 3        7.5170 -0.201952
# 4       13.1391 -0.738666
# 5       14.9643 -0.585724
# 6       21.4045 -0.046069
# 10      13.5980 -0.700213
# 15       8.7735  0.071797
# 16       7.2090 -0.269055
# 17      19.0671 -0.241931
# 21      22.1325  0.014933
# 27      23.5677  0.135196
# 28      14.0998 -0.658165
# 31       9.3620  0.200011
# 37      21.3863 -0.047594
# 38      25.2512  0.276264
# 39      21.8491 -0.008814
# 40      35.3525  5.862465
# 46      23.8043  0.155021
# 48       6.4825 -0.427335
# 52       5.6285 -0.613393
# 53      25.3773  0.286831
# 54       8.7455  0.065696
# 61      22.0090  0.004585
# 63      15.6221 -0.530604
# 64      19.0749 -0.241277
# 66      40.7888  1.578233
# 72       7.7565 -0.149773
# 73       6.9830 -0.318293
# ..          ...       ...
# 244     23.6678  0.143584
# 245     20.6557 -0.108815
# 246     20.7441 -0.101407
# 249     25.9948  0.338574
# 252      8.1610 -0.061647
# 254      9.2270  0.170599
# 258     22.4107  0.038245
# 259     19.5793 -0.199011
# 261     15.3790 -0.550974
# 262     14.9240 -0.589101
# 263      9.0280  0.127244
# 264     13.1716 -0.735943
# 265     25.1823  0.270491
# 267     25.9142  0.331820
# 268     17.7541 -0.351953
# 270      9.1730  0.158834
# 272     22.6174  0.055566
# 273      9.2200  0.169074
# 276     19.4142 -0.212846
# 277    111.5868  7.510733
# 279      5.2345 -0.699232
# 283      8.3765 -0.014696
# 284     21.9674  0.001099
# 287     14.1713 -0.652173
# 290     24.4465  0.208834
# 291     18.5952 -0.281474
# 293     24.3412  0.200011
# 296      6.7895 -0.360450
# 298     17.0690 -0.409361
# 299     25.1420  0.267114
#
# [136 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]= 12,5
plt.rcParams.update({'font.size': 16})

# %%
plt.plot(thdata.z_score, color='green', marker='o', linestyle='')
plt.xlabel("Index", fontsize=22)
plt.ylabel("Z Score", fontsize=22)
plt.grid(color='grey', linestyle='--')

# %%
thdata[thdata.z_score > 1.5]
# Out:
#      trans_date          uploader     vendor  amount tax_type  tax_rate  \
# 40   2018-03-15  Charles M. Burns  tinyhouse  707.05      GST         5
# 66   2018-05-08  Charles M. Burns  tinyhouse  313.76      HST        13
# 232  2019-01-11  Charles M. Burns  tinyhouse  448.23      HST        13
# 239  2019-01-17  Charles M. Burns  tinyhouse  535.89      GST         5
# 277  2019-04-09  Charles M. Burns  tinyhouse  858.36      HST        13
#
#      tax_amount   z_score
# 40      35.3525  5.862465
# 66      40.7888  1.578233
# 232     58.2699  3.043057
# 239     26.7945  3.997965
# 277    111.5868  7.510733
